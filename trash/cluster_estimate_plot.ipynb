# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
clusters = [2, 5, 10, 25, 50, 75]
tols = [0.1, 0.5, 1]

ndim = [2, 10]
num_records = pd.read_csv("results/benpsa/dim2num_records.csv")
mp_num_records = pd.read_csv("results/benpsa/dim2mp_num_records.csv")

iter_records_1 = pd.read_csv("results/benpsa/dim2iter_records_1.csv")
start_inertia_1 = pd.read_csv("results/benpsa/dim2start_inertia_1.csv")
end_inertia_1 = pd.read_csv("results/benpsa/dim2end_inertia_1.csv")

iter_records_1 = pd.read_csv("results/benpsa/dim2iter_records_1.csv")
start_inertia_1 = pd.read_csv("results/benpsa/dim2start_inertia_1.csv")
end_inertia_1 = pd.read_csv("results/benpsa/dim2end_inertia_1.csv")

mp_iter_records_1 = pd.read_csv("results/benpsa/dim2mp_iter_records_1.csv")
mp_start_inertia_1 = pd.read_csv("results/benpsa/dim2mp_start_inertia_1.csv")
mp_end_inertia_1 = pd.read_csv("results/benpsa/dim2mp_end_inertia_1.csv")

mp_iter_records_2 = pd.read_csv("results/benpsa/dim2mp_iter_records_2.csv")
mp_start_inertia_2 = pd.read_csv("results/benpsa/dim2mp_start_inertia_2.csv")
mp_end_inertia_2 = pd.read_csv("results/benpsa/dim2mp_end_inertia_2.csv")

# %%
plt.plot(clusters, start_inertia_1.values[:, 1], label=r'$\alpha$=0.1')
plt.plot(clusters, start_inertia_1.values[:, 2], label=r'$\alpha$=0.5')
plt.plot(clusters, start_inertia_1.values[:, 3], label=r'$\alpha$=1')

plt.plot(clusters, mp_num_records.values[:, 1], label=r'$\alpha$=0.1 (mp)')
plt.plot(clusters, mp_num_records.values[:, 2], label=r'$\alpha$=0.5 (mp)')
plt.plot(clusters, mp_num_records.values[:, 3], label=r'$\alpha$=1 (mp)')
plt.legend()
plt.xlabel('ground truth clusters')
plt.title('2 dimensions')
plt.grid()
plt.ylabel('clusters')
# Out:
# Text(0, 0.5, 'clusters')

# %%
plt.plot(clusters, num_records.values[:, 1], label=r'$\alpha$=0.1')
plt.plot(clusters, num_records.values[:, 2], label=r'$\alpha$=0.5')
plt.plot(clusters, num_records.values[:, 3], label=r'$\alpha$=1')

plt.plot(clusters, mp_num_records.values[:, 1], label=r'$\alpha$=0.1 (mp)')
plt.plot(clusters, mp_num_records.values[:, 2], label=r'$\alpha$=0.5 (mp)')
plt.plot(clusters, mp_num_records.values[:, 3], label=r'$\alpha$=1 (mp)')
plt.legend()
plt.xlabel('ground truth clusters')
plt.title('2 dimensions')
plt.grid()
plt.ylabel('clusters')
# Out:
# Text(0, 0.5, 'clusters')

# %%
clusters = [2, 5, 10, 25, 50, 75]
tols = [0.1, 0.5, 1]

ndim = [2, 10]
num_records = pd.read_csv("results/benpsa/dim10num_records.csv")
mp_num_records = pd.read_csv("results/benpsa/dim10mp_num_records.csv")

iter_records_1 = pd.read_csv("results/benpsa/dim10iter_records_1.csv")
start_inertia_1 = pd.read_csv("results/benpsa/dim10start_inertia_1.csv")
end_inertia_1 = pd.read_csv("results/benpsa/dim10end_inertia_1.csv")

iter_records_1 = pd.read_csv("results/benpsa/dim10iter_records_1.csv")
start_inertia_1 = pd.read_csv("results/benpsa/dim10start_inertia_1.csv")
end_inertia_1 = pd.read_csv("results/benpsa/dim10end_inertia_1.csv")

mp_iter_records_1 = pd.read_csv("results/benpsa/dim10mp_iter_records_1.csv")
mp_start_inertia_1 = pd.read_csv("results/benpsa/dim10mp_start_inertia_1.csv")
mp_end_inertia_1 = pd.read_csv("results/benpsa/dim10mp_end_inertia_1.csv")

mp_iter_records_2 = pd.read_csv("results/benpsa/dim10mp_iter_records_2.csv")
mp_start_inertia_2 = pd.read_csv("results/benpsa/dim10mp_start_inertia_2.csv")
mp_end_inertia_2 = pd.read_csv("results/benpsa/dim10mp_end_inertia_2.csv")

# %%
plt.plot(clusters, num_records.values[:, 1], label=r'$\alpha$=0.1')
plt.plot(clusters, num_records.values[:, 2], label=r'$\alpha$=0.5')
plt.plot(clusters, num_records.values[:, 3], label=r'$\alpha$=1')

plt.plot(clusters, mp_num_records.values[:, 1], label=r'$\alpha$=0.1 (mp)')
plt.plot(clusters, mp_num_records.values[:, 2], label=r'$\alpha$=0.5 (mp)')
plt.plot(clusters, mp_num_records.values[:, 3], label=r'$\alpha$=1 (mp)')
plt.legend()
plt.xlabel('ground truth clusters')
plt.title('10 dimensions')
plt.grid()
plt.ylabel('clusters')
# Out:
# Text(0, 0.5, 'clusters')
